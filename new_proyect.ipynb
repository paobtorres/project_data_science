# %% [markdown]
# <b><font size=8 color='#F0CF78'> Estructurando un Proyecto de DS (Parte III)</font></b>

# %% [markdown]
# ![Storms-Images.jpg](attachment:Storms-Images.jpg)

# %% [markdown]
#  <b><font size=6 color='#78945F'> Índice de Contenido</font></b>
#
#  ---
#
# <b><font size = 5 color='#99495C'> 1 </font><font size = 5 color="#F4AC73">|</font> <font size = 5 color='#CDAE7D'>[Abstract](#abstract)</font></b>
#
# <b><font size = 5 color='#99495C'> 2 </font><font size = 5 color="#F4AC73">|</font> <font size = 5 color='#CDAE7D'>[Motivación](#motivacion)</font></b>
#
# <b><font size = 5 color='#99495C'> 3 </font><font size = 5 color="#F4AC73">|</font> <font size = 5 color='#CDAE7D'>[Audiencia](#audiencia)</font></b>
#
# <b><font size = 5 color='#99495C'> 4 </font><font size = 5 color="#F4AC73">|</font> <font size = 5 color='#CDAE7D'>[Definición de Objetivo](#objetivo)</font></b>
#
# <b><font size = 5 color='#99495C'> 5 </font><font size = 5 color="#F4AC73">|</font> <font size = 5 color='#CDAE7D'>[Contexto Comercial](#contextocomercial)</font></b>
#
# <b><font size = 5 color='#99495C'> 6 </font><font size = 5 color="#F4AC73">|</font> <font size = 5 color='#CDAE7D'>[Problema Comercial](#problemacomercial)</font></b>
#
# <b><font size = 5 color='#99495C'> 7 </font><font size = 5 color="#F4AC73">|</font> <font size = 5 color='#CDAE7D'>[Contexto Analítico](#contextoanalitico)</font></b>
#
# <!-- <b><font size = 4 color='#99495C'> 7.1 </font><font size = 4 color="#F4AC73">|</font> <font size = 4 color='#CDAE7D'>[Importación de Librerias](#importacion)</font></b>
#
# <b><font size = 4 color='#99495C'> 7.2 </font><font size = 4 color="#F4AC73">|</font> <font size = 4 color='#CDAE7D'>[Dataset](#dataset)</font></b> -->
#
# <b><font size = 5 color='#99495C'> 8 </font><font size = 5 color="#F4AC73">|</font> <font size = 5 color='#CDAE7D'>[Análisis Exploratorio de Datos (EDA)](#eda)</font></b>
#
# <!-- <b><font size = 4 color='#99495C'> 7.1 </font><font size = 4 color="#F4AC73">|</font> <font size = 4 color='#CDAE7D'>[Importación de Librerias](#contextoanalitico)</font></b> -->
#
# <b><font size = 5 color='#99495C'> 9 </font><font size = 5 color="#F4AC73">|</font> <font size = 5 color='#CDAE7D'>[Feature Engineering](#feature)</font></b>
#
# <b><font size = 5 color='#99495C'> 10 </font><font size = 5 color="#F4AC73">|</font> <font size = 5 color='#CDAE7D'>[Elección de un Modelo](#modelo)</font></b>
#
# <b><font size = 5 color='#99495C'> 11 </font><font size = 5 color="#F4AC73">|</font> <font size = 5 color='#CDAE7D'>[Storytelling](#storytelling)</font></b>
#
#
#
#
# <!-- <b><font size=6 color='#99495C'> 01</font></b>
# <b><font color='#F4AC73'> 01</font></b>
# <b><font color='#F0CF78'> 01</font></b>
# <b><font color='#CDAE7D'> 01</font></b>
# <b><font color='#78945F'> 01</font></b> -->

# %% [markdown]
# ______________________

# %% [markdown]
# ## <b><font size = 5 color='#99495C'> 1 </font><font size = 5 color="#F4AC73">|</font> <font size = 5 color='#CDAE7D'>Abstract</font></b><a name="abstract"></a>

# %% [markdown]
# ## <b><font size = 5 color='#99495C'> 2 </font><font size = 5 color="#F4AC73">|</font> <font size = 5 color='#CDAE7D'>Motivacion</font></b><a name="motivacion"></a>

# %% [markdown]
# ## <b><font size = 5 color='#99495C'> 3 </font><font size = 5 color="#F4AC73">|</font> <font size = 5 color='#CDAE7D'>Audiencia</font></b><a name="audiencia"></a>

# %% [markdown]
# ## <b><font size = 5 color='#99495C'> 4 </font><font size = 5 color="#F4AC73">|</font> <font size = 5 color='#CDAE7D'>Definición de objetivo</font></b><a name="objetivo"></a>

# %% [markdown]
# ## <b><font size = 5 color='#99495C'> 5 </font><font size = 5 color="#F4AC73">|</font> <font size = 5 color='#CDAE7D'>Contexto Comercial</font></b><a name="contextocomercial"></a>

# %% [markdown]
# ## <b><font size = 5 color='#99495C'> 6 </font><font size = 5 color="#F4AC73">|</font> <font size = 5 color='#CDAE7D'>Problema Comercial</font></b><a name="problemacomercial"></a>

# %% [markdown]
# ## <b><font size = 5 color='#99495C'> 7 </font><font size = 5 color="#F4AC73">|</font> <font size = 5 color='#CDAE7D'>Contexto Analítico</font></b><a name="contextoanalitico"></a>

# %% [markdown]
# ### <b><font size = 5 color='#99495C'> 7.1 </font><font size = 5 color="#F4AC73">|</font> <font size = 5 color='#CDAE7D'>Importación de Librerías</font></b><a name="librerias"></a>

# %%
# Tratamiento de datos
# ==============================================================================
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, OneHotEncoder, LabelEncoder
from sklearn.impute import SimpleImputer

# Gráficos
# ==============================================================================
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno

# Preprocesado y modelado
# ==============================================================================
from sklearn.model_selection import train_test_split
from sklearn.pipeline import make_pipeline

# Feature Engineering
from sklearn.inspection import PartialDependenceDisplay
from sklearn.preprocessing import PolynomialFeatures
from sklearn.inspection import permutation_importance

# Reducción de dimensionalidad
from sklearn.decomposition import PCA

# Detección de outliers
from sklearn.ensemble import IsolationForest

# Modelos de Regresión
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor # NUEVO
from catboost import CatBoostRegressor # NUEVO
from lightgbm import LGBMRegressor # NUEVO

# Modelos de Clasificación
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier # NUEVO
from catboost import CatBoostClassifier # NUEVO
from lightgbm import LGBMClassifier # NUEVO

# Selección de Modelos
from sklearn.model_selection import GridSearchCV, cross_val_score, RandomizedSearchCV
# from skopt import BayesSearchCV
# from skopt.space import Real, Categorical, Integer
# from scipy.stats import randint

# Modelos de Clustering
from sklearn.cluster import KMeans, AgglomerativeClustering, DBSCAN

# Métricas
# ==============================================================================
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error, r2_score
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score, f1_score, roc_auc_score, roc_curve
# Defino Semilla
SEED = 32148

# Drive
# from google.colab import drive
# drive.mount('/content/drive')

# %% [markdown]
# ### <b><font size = 5 color='#99495C'> 7.2 </font><font size = 5 color="#F4AC73">|</font> <font size = 5 color='#CDAE7D'>Dataset</font></b><a name="dataset"></a>

# %%
df = pd.read_csv('datasets/2023_stormevents_details.csv')

df.head()
# Out:
#    BEGIN_YEARMONTH  BEGIN_DAY  BEGIN_TIME  END_YEARMONTH  END_DAY  END_TIME  \
# 0           202310         25         230         202310       27       551
# 1           202310         25         230         202310       27      1437
# 2           202310         25         230         202310       27      1126
# 3           202310         25         230         202310       27      1301
# 4           202310         25         230         202310       27       600
#
#    EPISODE_ID  EVENT_ID         STATE  STATE_FIPS  ...  END_RANGE END_AZIMUTH  \
# 0      186682   1145781  NORTH DAKOTA          38  ...        NaN         NaN
# 1      186682   1145783  NORTH DAKOTA          38  ...        NaN         NaN
# 2      186682   1145784  NORTH DAKOTA          38  ...        NaN         NaN
# 3      186682   1145796  NORTH DAKOTA          38  ...        NaN         NaN
# 4      186682   1145884  NORTH DAKOTA          38  ...        NaN         NaN
#
# ...

# %%
df.columns
# Out:
# Index(['FAT_YEARMONTH', 'FAT_DAY', 'FAT_TIME', 'FATALITY_ID', 'EVENT_ID',
#        'FATALITY_TYPE', 'FATALITY_DATE', 'FATALITY_AGE', 'FATALITY_SEX',
#        'FATALITY_LOCATION', 'EVENT_YEARMONTH'],
#       dtype='object')

# %%
df2 = pd.read_csv('datasets/2023_stormevents_fatalities.csv')

df2.head()
# Out:
#    FAT_YEARMONTH  FAT_DAY  FAT_TIME  FATALITY_ID  EVENT_ID FATALITY_TYPE  \
# 0         202307       29         0        49378   1108090             D
# 1         202307       29         0        49359   1108167             D
# 2         202307       27         0        49455   1109732             D
# 3         202307       28         0        50209   1128929             D
# 4         202307       28         0        50230   1131465             D
#
#          FATALITY_DATE  FATALITY_AGE FATALITY_SEX FATALITY_LOCATION  \
# 0  07/29/2023 00:00:00          75.0            M    Permanent Home
# 1  07/29/2023 00:00:00          44.0            M    Permanent Home
# 2  07/27/2023 00:00:00          53.0            F    Permanent Home
# 3  07/28/2023 00:00:00          52.0            F    Permanent Home
# 4  07/28/2023 00:00:00           7.0            M          In Water
#
#    EVENT_YEARMONTH
# 0           202307
# 1           202307
# 2           202307
# 3           202307
# ...

# %% [markdown]
# #### <b><font color='#99495C'> 7.2.1 </font><font color="#F4AC73">|</font> <font color='#CDAE7D'>Información General</font></b><a name="infogeneral"></a>

# %%
#Reviso la cantidad de filas y columnas totales
print (f'Shape: {df.shape}' )

# Información del dtype de las columnas
df.info()

# Visualización general y rápida de metricas
df.describe()
# Out:
# Shape: (74909, 51)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74909 entries, 0 to 74908
# Data columns (total 51 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   BEGIN_YEARMONTH     74909 non-null  int64
#  1   BEGIN_DAY           74909 non-null  int64
#  2   BEGIN_TIME          74909 non-null  int64
#  3   END_YEARMONTH       74909 non-null  int64
#  4   END_DAY             74909 non-null  int64
#  5   END_TIME            74909 non-null  int64
#  6   EPISODE_ID          74909 non-null  int64
#  7   EVENT_ID            74909 non-null  int64
#  8   STATE               74909 non-null  object
#  9   STATE_FIPS          74909 non-null  int64
#  10  YEAR                74909 non-null  int64
#  11  MONTH_NAME          74909 non-null  object
#  12  EVENT_TYPE          74909 non-null  object
#  13  CZ_TYPE             74909 non-null  object
#  14  CZ_FIPS             74909 non-null  int64
# ...

# %% [markdown]
# #### <b><font color='#99495C'> 7.2.2 </font><font color="#F4AC73">|</font> <font color='#CDAE7D'>Cambios en el df: Datetime</font></b><a name="infogeneral"></a>

# %%
# # Creo columnas para dividir la fecha
df['BEGIN_YEARMONTH'] = pd.to_datetime(df['BEGIN_YEARMONTH'] ).dt.to_period('M')
df['END_YEARMONTH'] = pd.to_datetime(df['END_YEARMONTH'] ).dt.to_period('M')
# # Validación
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74909 entries, 0 to 74908
# Data columns (total 51 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   BEGIN_YEARMONTH     74909 non-null  period[M]
#  1   BEGIN_DAY           74909 non-null  int64
#  2   BEGIN_TIME          74909 non-null  int64
#  3   END_YEARMONTH       74909 non-null  period[M]
#  4   END_DAY             74909 non-null  int64
#  5   END_TIME            74909 non-null  int64
#  6   EPISODE_ID          74909 non-null  int64
#  7   EVENT_ID            74909 non-null  int64
#  8   STATE               74909 non-null  object
#  9   STATE_FIPS          74909 non-null  int64
#  10  YEAR                74909 non-null  int64
#  11  MONTH_NAME          74909 non-null  object
#  12  EVENT_TYPE          74909 non-null  object
#  13  CZ_TYPE             74909 non-null  object
#  14  CZ_FIPS             74909 non-null  int64
# ...

# %% [markdown]
# ## <b><font size = 5 color='#99495C'> 8 </font><font size = 5 color="#F4AC73">|</font> <font size = 5 color='#CDAE7D'>Análisis Exploratorio de Datos (EDA) </font></b><a name="eda"></a>

# %% [markdown]
# ### <b><font color='#99495C'> 8.1 </font><font  color="#F4AC73">|</font> <font  color='#CDAE7D'>Análisis de Parámetros principales</font></b><a name="analisisparametros"></a>

# %%
fig, ax = plt.subplots(figsize=(12, 5))

# sns.boxplot (data = df_filtered, x = 'Beer_Style', y = 'Loss_During_Brewing', hue = 'Location')
# sns.move_legend(ax,'upper center', bbox_to_anchor=(0.5,1.3), ncol=5
#                  , title=None, frameon=False)

# ax.set_title('Pérdidas en Etapa de Elaboración para los distintos estilos de cerveza')
# ax.set_xlabel('')
# ax.set_ylabel('Pérdidas en la Elaboración')

# plt.show()

# %% [markdown]
# ## <b><font size = 5 color='#99495C'> 9 </font><font size = 5 color="#F4AC73">|</font> <font size = 5 color='#CDAE7D'> Data Wrangling </font></b><a name="wrangling"></a>

# %% [markdown]
# ### <b><font color='#99495C'> 9.1 </font><font  color="#F4AC73">|</font> <font  color='#CDAE7D'> Analisis de Nulos</font></b><a name="nulos"></a>

# %%
df.isnull().sum()
# Out:
# BEGIN_YEARMONTH           0
# BEGIN_DAY                 0
# BEGIN_TIME                0
# END_YEARMONTH             0
# END_DAY                   0
# END_TIME                  0
# EPISODE_ID                0
# EVENT_ID                  0
# STATE                     0
# STATE_FIPS                0
# YEAR                      0
# MONTH_NAME                0
# EVENT_TYPE                0
# CZ_TYPE                   0
# CZ_FIPS                   0
# CZ_NAME                   0
# WFO                       0
# BEGIN_DATE_TIME           0
# CZ_TIMEZONE               0
# END_DATE_TIME             0
# INJURIES_DIRECT           0
# INJURIES_INDIRECT         0
# DEATHS_DIRECT             0
# DEATHS_INDIRECT           0
# DAMAGE_PROPERTY       17752
# DAMAGE_CROPS          18259
# SOURCE                    0
# MAGNITUDE             34828
# MAGNITUDE_TYPE        46541
# FLOOD_CAUSE           68297
# CATEGORY              74893
# TOR_F_SCALE           73418
# TOR_LENGTH            73418
# ...

# %% [markdown]
# ### <b><font color='#99495C'> 9.2 </font><font  color="#F4AC73">|</font> <font  color='#CDAE7D'> Analisis de Duplicados</font></b><a name="duplicados"></a>

# %%
duplicateRows = df[df.duplicated()]

# %% [markdown]
# ### <b><font color='#99495C'> 9.3 </font><font  color="#F4AC73">|</font> <font  color='#CDAE7D'> Label Encoder</font></b><a name="labelencoder"></a>

# %% [markdown]
# ## <b><font size = 5 color='#99495C'> 10 </font><font size = 5 color="#F4AC73">|</font> <font size = 5 color='#CDAE7D'> Feature Engineering </font></b><a name="feature"></a>

# %% [markdown]
# ## <b><font size = 5 color='#99495C'> 11 </font><font size = 5 color="#F4AC73">|</font> <font size = 5 color='#CDAE7D'> Elección de un modelo </font></b><a name="modelo"></a>
