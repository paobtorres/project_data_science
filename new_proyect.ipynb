# %% [markdown]
# <b><font size = 5 color='#99495C'> 10 </font><font size = 5 color="#F4AC73">|</font> <font size = 5 color='#CDAE7D'> Feature Engineering </font></b><a name="feature"></a>

# %% [markdown]
# <b><font size = 5 color='#99495C'> 10 </font><font size = 5 color="#F4AC73">|</font> <font size = 5 color='#CDAE7D'> Feature Engineering </font></b><a name="feature"></a>

# %%
# Tratamiento de datos
# ==============================================================================
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, OneHotEncoder, LabelEncoder
from sklearn.impute import SimpleImputer

# Gráficos
# ==============================================================================
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno

# Preprocesado y modelado
# ==============================================================================
from sklearn.model_selection import train_test_split
from sklearn.pipeline import make_pipeline

# Feature Engineering
from sklearn.inspection import PartialDependenceDisplay
from sklearn.preprocessing import PolynomialFeatures
from sklearn.inspection import permutation_importance

# Reducción de dimensionalidad
from sklearn.decomposition import PCA

# Detección de outliers
from sklearn.ensemble import IsolationForest

# Modelos de Regresión
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor # NUEVO
from catboost import CatBoostRegressor # NUEVO
from lightgbm import LGBMRegressor # NUEVO

# Modelos de Clasificación
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier # NUEVO
from catboost import CatBoostClassifier # NUEVO
from lightgbm import LGBMClassifier # NUEVO

# Selección de Modelos
from sklearn.model_selection import GridSearchCV, cross_val_score, RandomizedSearchCV
from skopt import BayesSearchCV
from skopt.space import Real, Categorical, Integer
from scipy.stats import randint

# Modelos de Clustering
from sklearn.cluster import KMeans, AgglomerativeClustering, DBSCAN

# Métricas
# ==============================================================================
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error, r2_score
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score, f1_score, roc_auc_score, roc_curve
# Defino Semilla
SEED = 32148

# Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20408/1299857836.py in <module>
#      33 from sklearn.svm import SVR
#      34 from sklearn.ensemble import RandomForestRegressor
# ---> 35 from xgboost import XGBRegressor # NUEVO
#      36 from catboost import CatBoostRegressor # NUEVO
#      37 from lightgbm import LGBMRegressor # NUEVO
#
# ModuleNotFoundError: No module named 'xgboost'

# %%
df1 = pd.read_csv('datasets/StormEvents_details-ftp_v1.0_d2023_c20240418.csv')

df1.head()

# df1.info()
# print (df1.info)
# print (df1.shape)
# Out:
#    BEGIN_YEARMONTH  BEGIN_DAY  BEGIN_TIME  END_YEARMONTH  END_DAY  END_TIME  \
# 0           202310         25         230         202310       27       551
# 1           202310         25         230         202310       27      1437
# 2           202310         25         230         202310       27      1126
# 3           202310         25         230         202310       27      1301
# 4           202310         25         230         202310       27       600
#
#    EPISODE_ID  EVENT_ID         STATE  STATE_FIPS  ...  END_RANGE END_AZIMUTH  \
# 0      186682   1145781  NORTH DAKOTA          38  ...        NaN         NaN
# 1      186682   1145783  NORTH DAKOTA          38  ...        NaN         NaN
# 2      186682   1145784  NORTH DAKOTA          38  ...        NaN         NaN
# 3      186682   1145796  NORTH DAKOTA          38  ...        NaN         NaN
# 4      186682   1145884  NORTH DAKOTA          38  ...        NaN         NaN
#
#   END_LOCATION BEGIN_LAT  BEGIN_LON END_LAT END_LON  \
# 0          NaN       NaN        NaN     NaN     NaN
# 1          NaN       NaN        NaN     NaN     NaN
# 2          NaN       NaN        NaN     NaN     NaN
# 3          NaN       NaN        NaN     NaN     NaN
# 4          NaN       NaN        NaN     NaN     NaN
#
#                                    EPISODE_NARRATIVE  \
# 0  In late October, a winter storm dumped heavy s...
# 1  In late October, a winter storm dumped heavy s...
# 2  In late October, a winter storm dumped heavy s...
# 3  In late October, a winter storm dumped heavy s...
# 4  In late October, a winter storm dumped heavy s...
#
#                                      EVENT_NARRATIVE DATA_SOURCE
# 0  Public reports 7.5 inches at Black Tiger Bay C...         CSV
# 1  Local Police Department relays storm total sno...         CSV
# 2  Public reports 10 inches of storm total snowfa...         CSV
# 3  Emergency Manager reports 6 inches of storm to...         CSV
# 4  CoCoRaHS Station ND-GF-23 reports 8.8 inches o...         CSV
#
# [5 rows x 51 columns]

# %%
df1.tail()
# Out:
#        BEGIN_YEARMONTH  BEGIN_DAY  BEGIN_TIME  END_YEARMONTH  END_DAY  \
# 74904           202308          1           0         202308        8
# 74905           202308          1           0         202308        8
# 74906           202308         20        1300         202308       25
# 74907           202306         24        1510         202306       24
# 74908           202307          3        1500         202307        3
#
#        END_TIME  EPISODE_ID  EVENT_ID      STATE  STATE_FIPS  ...  END_RANGE  \
# 74904      2259      184635   1130604   ILLINOIS          17  ...        NaN
# 74905      2259      184635   1130606   ILLINOIS          17  ...        NaN
# 74906      2000      183592   1122056   ILLINOIS          17  ...        NaN
# 74907      1514      182312   1114348  MINNESOTA          27  ...        4.0
# 74908      1500      183551   1121651   NEW YORK          36  ...        1.0
#
#       END_AZIMUTH END_LOCATION BEGIN_LAT  BEGIN_LON  END_LAT  END_LON  \
# 74904         NaN          NaN       NaN        NaN      NaN      NaN
# 74905         NaN          NaN       NaN        NaN      NaN      NaN
# 74906         NaN          NaN       NaN        NaN      NaN      NaN
# 74907         ENE       SHELLY     47.49     -96.73  47.4991 -96.7571
# 74908           E       GOSHEN     41.40     -74.31  41.4000 -74.3100
#
#                                        EPISODE_NARRATIVE  \
# 74904  Severe Drought (D2) persisted across west-cent...
# 74905  Severe Drought (D2) persisted across west-cent...
# 74906  A strong heat dome over the Midwest resulted i...
# 74907  Surface low pressure system tracked across the...
# 74908  A slow moving front and shortwave trough aloft...
#
#                                          EVENT_NARRATIVE DATA_SOURCE
# 74904  Severe Drought (D2) conditions lingered across...         CSV
# 74905  Severe Drought (D2) conditions lingered across...         CSV
# 74906  A prolonged stretch of dangerous heat and humi...         CSV
# 74907  Norman county Emergency Manager confirmed torn...         CSV
# 74908   Poles and wires down on Orange Avenue in Goshen.         CSV
#
# [5 rows x 51 columns]
